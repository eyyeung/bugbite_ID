# %% [markdown]
# # Serving the model -- run below to start the TF serving server
# * helpful links:
#     * https://www.analyticsvidhya.com/blog/2020/03/tensorflow-serving-deploy-deep-learning-models/
#     * https://towardsdatascience.com/deploying-deep-learning-models-using-tensorflow-serving-with-docker-and-flask-3b9a76ffbbda

# %%
import os
# MODEL_DIR = '/home/eyan/Desktop/'
MODEL_DIR = '/home/eyan/Desktop/bug_bite_old/models/bug_model/1'
os.environ["MODEL_DIR"] = MODEL_DIR

# %%
# this is running in bash -- could also be run in terminal

# running in the terminal
# !tensorflow_model_server --rest_api_port=8501 --model_base_path="path-to-directory/tensorflow_serving/my_model" --model_name=bug_model

# alternatively, run with docker : https://towardsdatascience.com/deploying-deep-learning-models-using-tensorflow-serving-with-docker-and-flask-3b9a76ffbbda

# %%
# %%bash --bg
# nohup tensorflow_model_server \
#   --rest_api_port=8501 \
#   --model_name=bug_model \
#   --model_base_path="${MODEL_DIR}" >server.log 2>&1

# %%
# this checks the server.log

# correct serving would have "NET_LOG: Entering the event loop ..."
# might need to refresh a few times before it works
# !tail server.log
# Out:
# 2020-06-11 11:17:03.002512: I tensorflow_serving/model_servers/server.cc:86] Building single TensorFlow model file config:  model_name: bug_model model_base_path: /home/eyan/Desktop/bug_bite_old/models/bug_model/1
# 2020-06-11 11:17:03.002753: I tensorflow_serving/model_servers/server_core.cc:464] Adding/updating models.
# 2020-06-11 11:17:03.002768: I tensorflow_serving/model_servers/server_core.cc:575]  (Re-)adding model: bug_model
# 2020-06-11 11:17:03.003228: W tensorflow_serving/sources/storage_path/file_system_storage_path_source.cc:267] No versions of servable bug_model found under base path /home/eyan/Desktop/bug_bite_old/models/bug_model/1
# 2020-06-11 11:17:03.289481: E tensorflow_serving/sources/storage_path/file_system_storage_path_source.cc:362] FileSystemStoragePathSource encountered a filesystem access error: Could not find base path /home/eyan/Desktop/bug_bite_old/models/1 for servable bug_model
# 2020-06-11 11:17:03.158489: E tensorflow_serving/sources/storage_path/file_system_storage_path_source.cc:362] FileSystemStoragePathSource encountered a filesystem access error: Could not find base path /home/eyan/Desktop/bug_bite_old/models/1 for servable bug_model
# 2020-06-11 11:17:02.966893: W tensorflow_serving/sources/storage_path/file_system_storage_path_source.cc:267] No versions of servable bug_model found under base path /home/eyan/Desktop/bug_bite_old/models/
# 2020-06-11 11:17:03.173196: E tensorflow_serving/sources/storage_path/file_system_storage_path_source.cc:362] FileSystemStoragePathSource encountered a filesystem access error: Could not find base path /home/eyan/Desktop/bug_bite_old/models/1 for servable bug_model
